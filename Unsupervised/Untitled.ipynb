# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.nunique()
# Out:
# CustomerID                200
# Gender                      2
# Age                        51
# Annual Income (k$)         64
# Spending Score (1-100)     84
# dtype: int64

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.rename(index=str, columns={'Annual Income (k$)': 'Income',
                              'Spending Score (1-100)': 'Score'}, inplace=True)
df.head()
# Out:
#    CustomerID  Gender  Age  Income  Score
# 0           1    Male   19      15     39
# 1           2    Male   21      15     81
# 2           3  Female   20      16      6
# 3           4  Female   23      16     77
# 4           5  Female   31      17     40

# %%
X = df.drop(['CustomerID', 'Gender'], axis=1)
sns.pairplot(df.drop('CustomerID', axis=1), hue='Gender', aspect=1.5)
plt.show()

# %%
from sklearn.cluster import KMeans

clusters = []

for i in range(1, 11):
    km = KMeans(n_clusters=i).fit(X)
    clusters.append(km.inertia_)
fig, ax = plt.subplots(figsize=(12, 8))
plt(x=list(range(1, 11)), y=clusters, ax=ax)
ax.set_title('Searching for Elbow')
ax.set_xlabel('Clusters')
ax.set_ylabel('Inertia')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-ee4d92381608> in <module>()
#       7     clusters.append(km.inertia_)
#       8 fig, ax = plt.subplots(figsize=(12, 8))
# ----> 9 plt(x=list(range(1, 11)), y=clusters, ax=ax)
#      10 ax.set_title('Searching for Elbow')
#      11 ax.set_xlabel('Clusters')
#
# TypeError: 'module' object is not callable

# %%
km3 = KMeans(n_clusters=3).fit(X)

X['Labels'] = km3.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(X['Income'], X['Score'], hue=X['Labels'], 
                palette=sns.color_palette('hls', 3))
plt.title('KMeans with 3 Clusters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-5a958cba84b8> in <module>()
#       4 plt.figure(figsize=(12, 8))
#       5 sns.regplot(X['Income'], X['Score'], hue=X['Labels'],
# ----> 6                 palette=sns.color_palette('hls', 3))
#       7 plt.title('KMeans with 3 Clusters')
#       8 plt.show()
#
# TypeError: regplot() got an unexpected keyword argument 'hue'
